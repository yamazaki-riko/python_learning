# %% [markdown]
# <a href="https://colab.research.google.com/github/yamazaki-riko/python_learning/blob/%E3%83%87%E3%83%BC%E3%82%BF%E5%88%86%E6%9E%90100%E6%9C%AC%E3%83%8E%E3%83%83%E3%82%AF/3%E7%AB%A0_%E9%A1%A7%E5%AE%A2%E3%81%AE%E5%85%A8%E4%BD%93%E5%83%8F%E3%82%92%E6%8A%8A%E6%8F%A1%E3%81%99%E3%82%8B%EF%BC%91%EF%BC%90%E6%9C%AC%E3%83%8E%E3%83%83%E3%82%AF.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Google Driveと接続を行います。これを行うことで、Driveにあるデータにアクセスできるようになります。
# 下記セルを実行すると、Googleアカウントのログインを求められますのでログインしてください。
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# 作業フォルダへの移動を行います。
# 人によって作業場所がことなるので、その場合作業場所を変更してください。
import os
os.chdir('/content/drive/MyDrive/100knock-data_analytics/3章') #ここを変更。

# %% [markdown]
# # 3章 顧客の全体像を把握する１０本ノック
#
# ここでは、スポーツジムの会員データを使って顧客の行動を分析していきます。
# これまでと同様にまずはデータを理解し、加工した後、
# 顧客の行動データを分析していきましょう。
# ここでは、機械学習に向けての初期分析を行います。

# %% [markdown]
# ### ノック21：データを読み込んで把握しよう

# %%
import pandas as pd

# %%
# 利用履歴データを読み込む（2018/04/01～2019/3/31）
uselog = pd.read_csv('use_log.csv')
# データの件数を表示
print(len(uselog))
# 先頭5行を表示
uselog.head()
# Out:
# 197428
#             log_id customer_id     usedate
# 0  L00000049012330    AS009373  2018-04-01
# 1  L00000049012331    AS015315  2018-04-01
# 2  L00000049012332    AS040841  2018-04-01
# 3  L00000049012333    AS046594  2018-04-01
# 4  L00000049012334    AS073285  2018-04-01

# %%
# 会員データを読み込む
customer = pd.read_csv('customer_master.csv')
print(len(customer))
customer.head()
# Out:
# 4192
#   customer_id   name class gender           start_date end_date campaign_id  \
# 0    OA832399   XXXX   C01      F  2015-05-01 00:00:00      NaN         CA1
# 1    PL270116  XXXXX   C01      M  2015-05-01 00:00:00      NaN         CA1
# 2    OA974876  XXXXX   C01      M  2015-05-01 00:00:00      NaN         CA1
# 3    HD024127  XXXXX   C01      F  2015-05-01 00:00:00      NaN         CA1
# 4    HD661448  XXXXX   C03      F  2015-05-01 00:00:00      NaN         CA1
#
#    is_deleted
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0

# %%
# 会員クラスデータを読み込む
class_master = pd.read_csv('class_master.csv')
print(len(class_master))
class_master.head()
# Out:
# 3
#   class class_name  price
# 0   C01     オールタイム  10500
# 1   C02      デイタイム   7500
# 2   C03        ナイト   6000

# %%
# キャンペーン区分を読み込む
campaign_master = pd.read_csv('campaign_master.csv')
print(len(campaign_master))
campaign_master.head()
# Out:
# 3
#   campaign_id campaign_name
# 0         CA1            通常
# 1         CA2         入会費半額
# 2         CA3         入会費無料

# %% [markdown]
# ### ノック22：顧客データを整形しよう

# %%
# 会員データと会員クラスデータを、classをキーにレフトジョイン
customer_join = pd.merge(customer, class_master, on='class', how='left')
# 会員データとキャンペーン区分データを、campaign_idをキーにレフトジョイン
customer_join = pd.merge(customer_join, campaign_master, on='campaign_id', how='left')
customer_join.head()
# Out:
#   customer_id   name class gender           start_date end_date campaign_id  \
# 0    OA832399   XXXX   C01      F  2015-05-01 00:00:00      NaN         CA1
# 1    PL270116  XXXXX   C01      M  2015-05-01 00:00:00      NaN         CA1
# 2    OA974876  XXXXX   C01      M  2015-05-01 00:00:00      NaN         CA1
# 3    HD024127  XXXXX   C01      F  2015-05-01 00:00:00      NaN         CA1
# 4    HD661448  XXXXX   C03      F  2015-05-01 00:00:00      NaN         CA1
#
#    is_deleted class_name  price campaign_name
# 0           0     オールタイム  10500            通常
# 1           0     オールタイム  10500            通常
# 2           0     オールタイム  10500            通常
# 3           0     オールタイム  10500            通常
# 4           0        ナイト   6000            通常

# %%
# 会員データと結合データの件数を確認
print(len(customer))
print(len(customer_join))
# Out:
# 4192
# 4192

# %%
# 欠損値を確認
customer_join.isnull().sum()
# Out:
# customer_id         0
# name                0
# class               0
# gender              0
# start_date          0
# end_date         2842
# campaign_id         0
# is_deleted          0
# class_name          0
# price               0
# campaign_name       0
# dtype: int64

# %% [markdown]
# ### ノック23：顧客データの基礎集計をしよう

# %%
# 会員クラスごとの会員数をカウント
customer_join.groupby('class_name').count()['customer_id']
# Out:
# class_name
# オールタイム    2045
# デイタイム     1019
# ナイト       1128
# Name: customer_id, dtype: int64

# %%
# キャンペーンごとの会員数をカウント
customer_join.groupby('campaign_name').count()['customer_id']
# Out:
# campaign_name
# 入会費半額     650
# 入会費無料     492
# 通常       3050
# Name: customer_id, dtype: int64

# %%
# 性別ごとの会員数をカウント
customer_join.groupby('gender').count()['customer_id']
# Out:
# gender
# F    1983
# M    2209
# Name: customer_id, dtype: int64

# %%
# 退会・在籍会員をカウント
customer_join.groupby('is_deleted').count()['customer_id']
# Out:
# is_deleted
# 0    2842
# 1    1350
# Name: customer_id, dtype: int64

# %%
# 入会日をdatetime型に変換
customer_join['start_date'] = pd.to_datetime(customer_join['start_date'])
# 2018/04/01以降の入会会員を取得
customer_start = customer_join.loc[customer_join['start_date'] >= pd.to_datetime('20180401')]
# 入会人数を表示
print(len(customer_start))
# Out:
# 1376

# %% [markdown]
# ### ノック24：最新顧客データの基礎集計をしよう

# %%
# 最新月の会員データを集計
# 退会日をdatetime型に変換
customer_join["end_date"] = pd.to_datetime(customer_join["end_date"])
# 退会日が2019/03/31以降の会員、もしくは退会していない会員を取得
customer_newer = customer_join.loc[(customer_join["end_date"] >= pd.to_datetime("20190331")) | (customer_join["end_date"].isna())]
# 最新月の会員を表示
print(len(customer_newer))
# ユニークな退会日を表示
customer_newer["end_date"].unique()
# Out:
# 2953
# <DatetimeArray>
# ['NaT', '2019-03-31 00:00:00']
# Length: 2, dtype: datetime64[ns]

# %%
# 会員クラスごとの会員数をカウント
customer_newer.groupby("class_name").count()["customer_id"]
# Out:
# class_name
# オールタイム    1444
# デイタイム      696
# ナイト        813
# Name: customer_id, dtype: int64

# %%
# キャンペーンごとの会員数をカウント
customer_newer.groupby("campaign_name").count()["customer_id"]
# Out:
# campaign_name
# 入会費半額     311
# 入会費無料     242
# 通常       2400
# Name: customer_id, dtype: int64

# %%
# 性別ごとの会員数をカウント
customer_newer.groupby("gender").count()["customer_id"]
# Out:
# gender
# F    1400
# M    1553
# Name: customer_id, dtype: int64

# %% [markdown]
# ### ノック25：利用履歴データを集計しよう

# %%
# 利用日時をdatetime型に変換
uselog["usedate"] = pd.to_datetime(uselog["usedate"])
# 文字列の年月カラムを作成
uselog["年月"] = uselog["usedate"].dt.strftime("%Y%m")
# 年月ごとの利用履歴をカウント
uselog_months = uselog.groupby(["年月", "customer_id"], as_index=False).count()
# log_idをcountにカラム名を変更
uselog_months.rename(columns={"log_id": "count"}, inplace=True)
# usedateは削除
del uselog_months["usedate"]
uselog_months
# Out:
#            年月 customer_id  count
# 0      201804    AS002855      4
# 1      201804    AS009013      2
# 2      201804    AS009373      3
# 3      201804    AS015315      6
# 4      201804    AS015739      7
# ...       ...         ...    ...
# 36837  201903    TS995853      8
# 36838  201903    TS998593      8
# 36839  201903    TS999079      3
# 36840  201903    TS999231      6
# 36841  201903    TS999855      4
#
# [36842 rows x 3 columns]

# %%
# 会員ごとの平均値、中央値、最大値、最小値を集計
uselog_customer = uselog_months.groupby("customer_id", as_index=False).agg(
    mean=("count", "mean"),
    median=("count", "median"),
    max=("count", "max"),
    min=("count", "min"),
)
# ?
uselog_customer = uselog_customer.reset_index(drop=False)
uselog_customer.head()
# Out:
#    index customer_id      mean  median  max  min
# 0      0    AS002855  4.500000     5.0    7    2
# 1      1    AS008805  4.000000     4.0    8    1
# 2      2    AS009013  2.000000     2.0    2    2
# 3      3    AS009373  5.083333     5.0    7    3
# 4      4    AS015233  7.545455     7.0   11    4

# %% [markdown]
# ### ノック26：利用履歴データから定期利用フラグを作成しよう

# %%
# 曜日カラムを作成
uselog["weekday"] = uselog["usedate"].dt.weekday
# 会員、年月、曜日ごとの利用数を集計
uselog_weekday = uselog.groupby(["customer_id", "年月", "weekday"], as_index=False)[["log_id"]].count()
# log_idをcountにカラム名を変更
uselog_weekday.rename(columns={"log_id": "count"}, inplace=True)
uselog_weekday.head()
# Out:
#   customer_id      年月  weekday  count
# 0    AS002855  201804        5      4
# 1    AS002855  201805        2      1
# 2    AS002855  201805        5      4
# 3    AS002855  201806        5      5
# 4    AS002855  201807        1      1

# %%
# 顧客ごとの最大値を取得
uselog_weekday = uselog_weekday.groupby("customer_id", as_index=False)[["count"]].max()
# routine_flgカラムを0で作成
uselog_weekday["routine_flg"] = 0
# 最大値が4以上の場合、フラグを立てる
uselog_weekday["routine_flg"] = uselog_weekday["routine_flg"].where(uselog_weekday["count"] < 4, 1)
uselog_weekday.head()
# Out:
#   customer_id  count  routine_flg
# 0    AS002855      5            1
# 1    AS008805      4            1
# 2    AS009013      2            0
# 3    AS009373      5            1
# 4    AS015233      5            1

# %% [markdown]
# ### ノック27：顧客データと利用履歴データを結合しよう

# %%
# 会員データと会員ごとの平均値、中央値、最大値、最小値を集計したデータを、customer_idをキーにレフトジョイン
customer_join = pd.merge(customer_join, uselog_customer, on="customer_id", how="left")
# 結合データにroutine_flgを結合
customer_join = pd.merge(customer_join, uselog_weekday[["customer_id", "routine_flg"]], on="customer_id", how="left")
customer_join.head()
# Out:
#   customer_id   name class gender start_date end_date campaign_id  is_deleted  \
# 0    OA832399   XXXX   C01      F 2015-05-01      NaT         CA1           0
# 1    PL270116  XXXXX   C01      M 2015-05-01      NaT         CA1           0
# 2    OA974876  XXXXX   C01      M 2015-05-01      NaT         CA1           0
# 3    HD024127  XXXXX   C01      F 2015-05-01      NaT         CA1           0
# 4    HD661448  XXXXX   C03      F 2015-05-01      NaT         CA1           0
#
#   class_name  price campaign_name  index      mean  median  max  min  \
# 0     オールタイム  10500            通常   3036  4.833333     5.0    8    2
# 1     オールタイム  10500            通常   3256  5.083333     5.0    7    3
# 2     オールタイム  10500            通常   3111  4.583333     5.0    6    3
# 3     オールタイム  10500            通常   1006  4.833333     4.5    7    2
# 4        ナイト   6000            通常   1331  3.916667     4.0    6    1
#
#    routine_flg
# 0            1
# 1            1
# 2            1
# ...

# %%
# 欠損値を確認
customer_join.isnull().sum()
# Out:
# customer_id         0
# name                0
# class               0
# gender              0
# start_date          0
# end_date         2842
# campaign_id         0
# is_deleted          0
# class_name          0
# price               0
# campaign_name       0
# index               0
# mean                0
# median              0
# max                 0
# min                 0
# routine_flg         0
# dtype: int64

# %% [markdown]
# ### ノック28：会員期間を計算しよう

# %%
from dateutil.relativedelta import relativedelta

# %%
# calc_dateカラムをend_dateで作成
customer_join["calc_date"] = customer_join["end_date"]
# 退会日がnullの場合は2019/04/30（?）を代入
customer_join["calc_date"] = customer_join["calc_date"].fillna(pd.to_datetime("20190430"))
# membership_periodカラムを0で作成
customer_join["membership_period"] = 0
for i in range(len(customer_join)):
    # 退会日から入会日までの期間を計算
    delta = relativedelta(customer_join["calc_date"].iloc[i], customer_join["start_date"].iloc[i])
    # 月単位で計算したいため、期間の年に12をかけ、残りの月を足す
    customer_join.loc[i, "membership_period"] = delta.years*12 + delta.months
customer_join.head()
# Out:
#   customer_id   name class gender start_date end_date campaign_id  is_deleted  \
# 0    OA832399   XXXX   C01      F 2015-05-01      NaT         CA1           0
# 1    PL270116  XXXXX   C01      M 2015-05-01      NaT         CA1           0
# 2    OA974876  XXXXX   C01      M 2015-05-01      NaT         CA1           0
# 3    HD024127  XXXXX   C01      F 2015-05-01      NaT         CA1           0
# 4    HD661448  XXXXX   C03      F 2015-05-01      NaT         CA1           0
#
#   class_name  price campaign_name  index      mean  median  max  min  \
# 0     オールタイム  10500            通常   3036  4.833333     5.0    8    2
# 1     オールタイム  10500            通常   3256  5.083333     5.0    7    3
# 2     オールタイム  10500            通常   3111  4.583333     5.0    6    3
# 3     オールタイム  10500            通常   1006  4.833333     4.5    7    2
# 4        ナイト   6000            通常   1331  3.916667     4.0    6    1
#
#    routine_flg  calc_date  membership_period
# ...

# %% [markdown]
# ### ノック29：顧客行動の各種統計量を把握しよう

# %%
# 会員ごとの平均値、中央値、最大値、最小値の、件数、平均値、標準偏差、最小値、四分位数、中央値、最大値を表示
customer_join[["mean", "median", "max", "min"]].describe()
# Out:
#               mean       median          max          min
# count  4192.000000  4192.000000  4192.000000  4192.000000
# mean      5.333127     5.250596     7.823950     3.041269
# std       1.777533     1.874874     2.168959     1.951565
# min       1.000000     1.000000     1.000000     1.000000
# 25%       4.250000     4.000000     7.000000     2.000000
# 50%       5.000000     5.000000     8.000000     3.000000
# 75%       6.416667     6.500000     9.000000     4.000000
# max      12.000000    12.000000    14.000000    12.000000

# %%
# routine_flgごとの会員数をカウント
customer_join.groupby("routine_flg")[["customer_id"]].count()
# Out:
#              customer_id
# routine_flg
# 0                    779
# 1                   3413

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline
# 在籍期間のグラフを表示
plt.hist(customer_join["membership_period"])
# Out:
# (array([857., 774., 395., 368., 311., 331., 323., 237., 288., 308.]),
#  array([ 1. ,  5.6, 10.2, 14.8, 19.4, 24. , 28.6, 33.2, 37.8, 42.4, 47. ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ### ノック30：退会ユーザーと継続ユーザーの違いを把握しよう

# %%
# 退会ユーザーの数値データの集計値を表示
customer_end = customer_join.select_dtypes(include="number").loc[customer_join["is_deleted"]==1]
customer_end.describe()
# Out:
#        is_deleted         price        index         mean       median  \
# count      1350.0   1350.000000  1350.000000  1350.000000  1350.000000
# mean          1.0   8595.555556  2030.260000     3.865474     3.621852
# std           0.0   1949.163652  1209.012998     1.246385     1.270847
# min           1.0   6000.000000     1.000000     1.000000     1.000000
# 25%           1.0   6000.000000   966.500000     3.000000     3.000000
# 50%           1.0   7500.000000  2019.000000     4.000000     4.000000
# 75%           1.0  10500.000000  3037.250000     4.666667     4.500000
# max           1.0  10500.000000  4184.000000     9.000000     9.000000
#
#                max          min  routine_flg  membership_period
# count  1350.000000  1350.000000  1350.000000        1350.000000
# mean      6.461481     1.821481     0.456296           8.026667
# std       2.584021     0.976361     0.498271           5.033692
# min       1.000000     1.000000     0.000000           1.000000
# ...

# %%
# 在籍ユーザーの数値データの集計値を表示
customer_stay = customer_join.select_dtypes(include="number").loc[customer_join["is_deleted"]==0]
customer_stay.describe()
# Out:
#        is_deleted         price        index         mean       median  \
# count      2842.0   2842.000000  2842.000000  2842.000000  2842.000000
# mean          0.0   8542.927516  2126.490148     6.030288     6.024279
# std           0.0   1977.189779  1209.847743     1.553587     1.599765
# min           0.0   6000.000000     0.000000     3.166667     3.000000
# 25%           0.0   6000.000000  1075.250000     4.833333     5.000000
# 50%           0.0   7500.000000  2131.500000     5.583333     5.500000
# 75%           0.0  10500.000000  3183.750000     7.178030     7.000000
# max           0.0  10500.000000  4191.000000    12.000000    12.000000
#
#                max          min  routine_flg  membership_period
# count  2842.000000  2842.000000  2842.000000        2842.000000
# mean      8.471147     3.620690     0.984166          23.970443
# std       1.571048     2.030488     0.124855          13.746761
# min       5.000000     1.000000     0.000000           1.000000
# ...

# %%
# csvファイルを出力
customer_join.to_csv("customer_join.csv", index=False)
